# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [24095,
23752.5,
23684.7,
25506.1,
36382.1]
memcelltype2 = [41004.7,
23317.4,
23219.6,
23214.7,
23603.6]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('IC Latency (in nanoseconds)', fontsize=14)
plt.title('IC Latency for Layer 1', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [16888.7,
16897.4,
16976.4,
18421.6,
26276.7]
memcelltype2 = [45996,
31381.6,
29550.9,
16766.7,
17047.5]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('IC Latency (in nanoseconds)', fontsize=14)
plt.title('IC Latency for Layer 2', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [13491.8,
13526,
13603,
14776,
21076.6]
memcelltype2 = [37670.3,
26165.8,
24579.9,
13448.6,
13673.8]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('IC Latency (in nanoseconds)', fontsize=14)
plt.title('IC Latency for Layer 3', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [12445,
12475.7,
12546.4,
13627.8,
19438.8]
memcelltype2 = [35613.6,
23863.3,
23544,
12403.5,
12611.3]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('IC Latency (in nanoseconds)', fontsize=14)
plt.title('IC Latency for Layer 4', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [4612.62,
4625.92,
4653.08,
5055.17,
7210.75]
memcelltype2 = [13164.5,
8966.44,
8693.61,
4601.04,
4678.12]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('IC Latency (in nanoseconds)', fontsize=14)
plt.title('IC Latency for Layer 5', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [8638.63,
8665.16,
8716.87,
9471.02,
13509.6]
memcelltype2 = [25174.7,
16808.6,
16807.6,
8620.19,
8764.59]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('IC Latency (in nanoseconds)', fontsize=14)
plt.title('IC Latency for Layer 6', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [195.462,
195.636,
196.589,
213.364,
304.345]
memcelltype2 = [362.699,
192.052,
192.729,
194.197,
197.45]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('IC Latency (in nanoseconds)', fontsize=14)
plt.title('IC Latency for Layer 7', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [172.405,
172.935,
173.968,
189.019,
269.619]
memcelltype2 = [323.531,
169.76,
170.552,
172.039,
174.92]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('IC Latency (in nanoseconds)', fontsize=14)
plt.title('IC Latency for Layer 8', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # How IC Latency varies with varying layers?

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
layers = ['Layer1', 'Layer2', 'Layer3', 'Layer4', 'Layer5', 'Layer6', 'Layer7', 'Layer8']
memcelltype1 = [24095,	16888.7,	13491.8,	12445,	4612.62,	8638.63,	195.462,	172.405]
memcelltype2 = [41004.7,	45996,	37670.3,	35613.6,	13164.5,	25174.7,	362.699,	323.531]

# Plot
bar_width = 0.35
index = np.arange(len(layers))

plt.figure(figsize=(12, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('Layers', fontsize=14)
plt.ylabel('IC Latency (in nanoseconds)', fontsize=14)
plt.title('IC Latency for numRowSubArray/numColSubArray = 64 in Param.cpp', fontsize=16)
plt.xticks(index + bar_width / 2, layers)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
layers = ['Layer1', 'Layer2', 'Layer3', 'Layer4', 'Layer5', 'Layer6', 'Layer7', 'Layer8']
memcelltype1 = [23752.5,	16897.4, 13526,	12475.7,	4625.92,	8665.16,	195.636,	172.935]
memcelltype2 = [23317.4, 31381.6,	26165.8, 23863.3,	8966.44,	16808.6, 192.052,	169.76]

# Plot
bar_width = 0.35
index = np.arange(len(layers))

plt.figure(figsize=(12, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('Layers', fontsize=14)
plt.ylabel('IC Latency (in nanoseconds)', fontsize=14)
plt.title('IC Latency for numRowSubArray/numColSubArray = 128 in Param.cpp', fontsize=16)
plt.xticks(index + bar_width / 2, layers)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
layers = ['Layer1', 'Layer2', 'Layer3', 'Layer4', 'Layer5', 'Layer6', 'Layer7', 'Layer8']
memcelltype1 = [23684.7,	16976.4,	13603,	12546.4,	4653.08,	8716.87,	196.589,	173.968]
memcelltype2 = [23219.6,	29550.9,	24579.9,	23544,	8693.61,	16807.6,	192.729,	170.552]
# Plot
bar_width = 0.35
index = np.arange(len(layers))

plt.figure(figsize=(12, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('Layers', fontsize=14)
plt.ylabel('IC Latency (in nanoseconds)', fontsize=14)
plt.title('IC Latency for numRowSubArray/numColSubArray = 256 in Param.cpp', fontsize=16)
plt.xticks(index + bar_width / 2, layers)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
layers = ['Layer1', 'Layer2', 'Layer3', 'Layer4', 'Layer5', 'Layer6', 'Layer7', 'Layer8']
memcelltype1 = [25506.1,	18421.6,	14776,	13627.8,	5055.17,	9471.02,	213.364,	189.019]
memcelltype2 = [23214.7,	16766.7,	13448.6	,12403.5,	4601.04,	8620.19,	194.197,	172.039]
# Plot
bar_width = 0.35
index = np.arange(len(layers))

plt.figure(figsize=(12, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('Layers', fontsize=14)
plt.ylabel('IC Latency (in nanoseconds)', fontsize=14)
plt.title('IC Latency for numRowSubArray/numColSubArray = 512 in Param.cpp', fontsize=16)
plt.xticks(index + bar_width / 2, layers)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
layers = ['Layer1', 'Layer2', 'Layer3', 'Layer4', 'Layer5', 'Layer6', 'Layer7', 'Layer8']
memcelltype1 = [36382.1,	26276.7,	21076.6,	19438.8,	7210.75,	13509.6,	304.345,	269.619]
memcelltype2 = [23603.6,	17047.5,	13673.8,	12611.3,	4678.12,	8764.59,	197.45,	174.92]
# Plot
bar_width = 0.35
index = np.arange(len(layers))

plt.figure(figsize=(12, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('Layers', fontsize=14)
plt.ylabel('IC Latency (in nanoseconds)', fontsize=14)
plt.title('IC Latency for numRowSubArray/numColSubArray = 1024 in Param.cpp', fontsize=16)
plt.xticks(index + bar_width / 2, layers)
plt.legend()

plt.tight_layout()
plt.show()
