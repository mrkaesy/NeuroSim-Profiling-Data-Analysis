# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [115856,115881,96024.5,54448.8,49402.8]
memcelltype2 = [113814,
113758,
94139.1,
49557.4,
32051]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('Buffer Latency (in nanoseconds)', fontsize=14)
plt.title('Buffer Latency for Layer 1', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [59506.9,
43602.3,
34244,
31679.4,
40505.7]
memcelltype2 = [58458.1,
42803.6,
33571.6,
28833.4,
26278.8]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('Buffer Latency (in nanoseconds)', fontsize=14)
plt.title('Buffer Latency for Layer 2', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [14080.5,
10388.2,
8228.72,
7670.93,
9870.65]
memcelltype2 = [13832.3,
10197.9,
8067.15,
6981.81,
6403.78]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('buffer Latency (in nanoseconds)', fontsize=14)
plt.title('buffer Latency for Layer 3', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [18566.1,
14888.6,
12756.4,
12590.9,
16888.5]
memcelltype2 = [18238.8,
14615.8,
12505.9,
11459.8,
10956.7]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('buffer Latency (in nanoseconds)', fontsize=14)
plt.title('buffer Latency for Layer 4', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [3770.99,
3040.21,
2619.3,
2596.23,
3494.3]
memcelltype2 = [3704.53,
2984.52,
2567.87,
2363,
2267]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('buffer Latency (in nanoseconds)', fontsize=14)
plt.title('buffer Latency for Layer 5', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [5823.23,
4985.8,
4514.48,
4622.81,
6360.19]
memcelltype2 = [5720.6,
4894.46,
4425.84,
4207.52,
4126.3]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('buffer Latency (in nanoseconds)', fontsize=14)
plt.title('buffer Latency for Layer 6', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [511.891,
500.454,
473.322,
454.904,
614.64]
memcelltype2 = [502.869,
491.286,
464.029,
414.038,
398.76]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('buffer Latency (in nanoseconds)', fontsize=14)
plt.title('buffer Latency for Layer 7', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [263.055,
263.686,
264.463,
285.101,
404.225]
memcelltype2 = [258.419,
258.856,
259.27,
259.489,
262.249]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('buffer Latency (in nanoseconds)', fontsize=14)
plt.title('buffer Latency for Layer 8', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # How Buffer Latency varies with varying layers?

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
layers = ['Layer1', 'Layer2', 'Layer3', 'Layer4', 'Layer5', 'Layer6', 'Layer7', 'Layer8']
memcelltype1 = [115856,59506.9,14080.5,18566.1,3770.99,5823.23,511.891,263.055]
memcelltype2 = [113814,58458.1,13832.3,18238.8,3704.53,5720.6,502.869,258.419]

# Plot
bar_width = 0.35
index = np.arange(len(layers))

plt.figure(figsize=(12, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('Layers', fontsize=14)
plt.ylabel('buffer Latency (in nanoseconds)', fontsize=14)
plt.title('buffer Latency for numRowSubArray/numColSubArray = 64 in Param.cpp', fontsize=16)
plt.xticks(index + bar_width / 2, layers)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
layers = ['Layer1', 'Layer2', 'Layer3', 'Layer4', 'Layer5', 'Layer6', 'Layer7', 'Layer8']
memcelltype1 = [115881,43602.3,10388.2,14888.6,3040.21,4985.8,500.454,263.686]
memcelltype2 = [113758,42803.6,10197.9,14615.8,2984.52,4894.46,491.286,258.856]

# Plot
bar_width = 0.35
index = np.arange(len(layers))

plt.figure(figsize=(12, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('Layers', fontsize=14)
plt.ylabel('buffer Latency (in pJ)', fontsize=14)
plt.title('buffer Latency for numRowSubArray/numColSubArray = 128 in Param.cpp', fontsize=16)
plt.xticks(index + bar_width / 2, layers)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
layers = ['Layer1', 'Layer2', 'Layer3', 'Layer4', 'Layer5', 'Layer6', 'Layer7', 'Layer8']
memcelltype1 = [96024.5,34244,8228.72,12756.4,2619.3,4514.48,473.322,264.463]
memcelltype2 = [94139.1,33571.6,8067.15,12505.9,2567.87,4425.84,464.029,259.27]

# Plot
bar_width = 0.35
index = np.arange(len(layers))

plt.figure(figsize=(12, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('Layers', fontsize=14)
plt.ylabel('buffer Latency (in pJ)', fontsize=14)
plt.title('buffer Latency for numRowSubArray/numColSubArray = 256 in Param.cpp', fontsize=16)
plt.xticks(index + bar_width / 2, layers)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
layers = ['Layer1', 'Layer2', 'Layer3', 'Layer4', 'Layer5', 'Layer6', 'Layer7', 'Layer8']
memcelltype1 = [54448.8,31679.4,7670.93,12590.9,2596.23,4622.81,454.904,285.101]
memcelltype2 = [49557.4,28833.4,6981.81,11459.8,2363,4207.52,414.038,259.489]

# Plot
bar_width = 0.35
index = np.arange(len(layers))

plt.figure(figsize=(12, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('Layers', fontsize=14)
plt.ylabel('buffer Latency (in pJ)', fontsize=14)
plt.title('buffer Latency for numRowSubArray/numColSubArray = 512 in Param.cpp', fontsize=16)
plt.xticks(index + bar_width / 2, layers)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
layers = ['Layer1', 'Layer2', 'Layer3', 'Layer4', 'Layer5', 'Layer6', 'Layer7', 'Layer8']
memcelltype1 = [49402.8,40505.7,9870.65,16888.5,3494.3,6360.1,614.64,404.225]
memcelltype2 = [32051,26278.8,6403.78,10956.7,2267,4126.3,398.76,262.249]

# Plot
bar_width = 0.35
index = np.arange(len(layers))

plt.figure(figsize=(12, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('Layers', fontsize=14)
plt.ylabel('buffer Latency (in pJ)', fontsize=14)
plt.title('buffer Latency for numRowSubArray/numColSubArray = 1024 in Param.cpp', fontsize=16)
plt.xticks(index + bar_width / 2, layers)
plt.legend()

plt.tight_layout()
plt.show()
