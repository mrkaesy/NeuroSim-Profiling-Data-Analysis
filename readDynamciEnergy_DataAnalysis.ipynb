# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [2232240, 2050400, 1987640, 1932470, 2326460]
memcelltype2 = [2416080, 1981540, 1782560, 1616330, 1910150]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('read Dynamic Energy (in pJ)', fontsize=14)
plt.title('Read Dynamic Energy for Layer 1', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [19450900, 17775200, 17152600, 16741300, 20515900]
memcelltype2 = [18388700, 15666500, 14377100, 13413400, 16111400]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('read Dynamic Energy (in pJ)', fontsize=14)
plt.title('Read Dynamic Energy for Layer 2', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [8285430, 7596310, 7340410, 7164210, 8705890]
memcelltype2 = [7848190, 6696920, 6152740, 5740390, 6866140]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('read Dynamic Energy (in pJ)', fontsize=14)
plt.title('Read Dynamic Energy for Layer 3', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [14708300, 13704700, 13183900, 12927700, 15295900]
memcelltype2 = [13003800, 11421000, 10671300, 10121600, 12027700]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('read Dynamic Energy (in pJ)', fontsize=14)
plt.title('Read Dynamic Energy for Layer 4', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [5486790, 5107110, 4797270, 4703640, 5552520]
memcelltype2 = [4730930, 4155780, 3883620, 3682750, 4372860]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('read Dynamic Energy (in pJ)', fontsize=14)
plt.title('Read Dynamic Energy for Layer 5', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [9972400, 9360780, 8779260, 8625410, 10126100]
memcelltype2 = [8338060, 7426970, 6994630, 6687840, 7973130]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('read Dynamic Energy (in pJ)', fontsize=14)
plt.title('Read Dynamic Energy for Layer 6', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [931037, 870342, 820946, 803759, 1577610]
memcelltype2 = [808185, 714257, 669964, 637287, 1227000]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('read Dynamic Energy (in pJ)', fontsize=14)
plt.title('Read Dynamic Energy for Layer 7', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [2138.04, 1957.64, 2177.72, 2671.4, 4035.37]
memcelltype2 = [3334.4, 2525.47, 2440.68, 2587.04, 3696.39]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('read Dynamic Energy (in pJ)', fontsize=14)
plt.title('Read Dynamic Energy for Layer 8', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # How Read Dynamic Energy varies with layers?

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
layers = ['Layer1', 'Layer2', 'Layer3', 'Layer4', 'Layer5', 'Layer6', 'Layer7', 'Layer8']
memcelltype1 = [2232240,	19450900,	8285430,	14708300,	5486790,	9972400,	931037,	2138.04]
memcelltype2 = [2416080	,18388700	,7848190,	13003800	,4730930	,8338060,	808185,	3334.4]

# Plot
bar_width = 0.35
index = np.arange(len(layers))

plt.figure(figsize=(12, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('Layers', fontsize=14)
plt.ylabel('Read Dynamic Energy (in pJ)', fontsize=14)
plt.title('Read Dynamic Energy for numRowSubArray/numColSubArray = 64 in Param.cpp', fontsize=16)
plt.xticks(index + bar_width / 2, layers)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
layers = ['Layer1', 'Layer2', 'Layer3', 'Layer4', 'Layer5', 'Layer6', 'Layer7', 'Layer8']
memcelltype1 = [2050400,	17775200,	7596310,	13704700	,5107110	,9360780,	870342	,1957.64]
memcelltype2 = [1981540	,15666500,	6696920,	11421000,	4155780	,7426970	,714257,	2525.47]

# Plot
bar_width = 0.35
index = np.arange(len(layers))

plt.figure(figsize=(12, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('Layers', fontsize=14)
plt.ylabel('Read Dynamic Energy (in pJ)', fontsize=14)
plt.title('Read Dynamic Energy for numRowSubArray/numColSubArray = 128 in Param.cpp', fontsize=16)
plt.xticks(index + bar_width / 2, layers)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
layers = ['Layer1', 'Layer2', 'Layer3', 'Layer4', 'Layer5', 'Layer6', 'Layer7', 'Layer8']
memcelltype1 = [1987640	,17152600	,7340410	,13183900	,4797270	,8779260	,820946,	2177.72]
memcelltype2 = [1782560	,14377100	,6152740	,10671300	,3883620	,6994630	,669964,	2440.68]

# Plot
bar_width = 0.35
index = np.arange(len(layers))

plt.figure(figsize=(12, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('Layers', fontsize=14)
plt.ylabel('Read Dynamic Energy (in pJ)', fontsize=14)
plt.title('Read Dynamic Energy for numRowSubArray/numColSubArray = 256 in Param.cpp', fontsize=16)
plt.xticks(index + bar_width / 2, layers)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
layers = ['Layer1', 'Layer2', 'Layer3', 'Layer4', 'Layer5', 'Layer6', 'Layer7', 'Layer8']
memcelltype1 = [1932470	,16741300	,7164210,	12927700,	4703640,	8625410,	803759	,2671.4]
memcelltype2 = [1616330	,13413400	,5740390	,10121600	,3682750,	6687840,	637287	,2587.04]

# Plot
bar_width = 0.35
index = np.arange(len(layers))

plt.figure(figsize=(12, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('Layers', fontsize=14)
plt.ylabel('Read Dynamic Energy (in pJ)', fontsize=14)
plt.title('Read Dynamic Energy for numRowSubArray/numColSubArray = 512 in Param.cpp', fontsize=16)
plt.xticks(index + bar_width / 2, layers)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
layers = ['Layer1', 'Layer2', 'Layer3', 'Layer4', 'Layer5', 'Layer6', 'Layer7', 'Layer8']
memcelltype1 = [2326460	,20515900,	8705890,	15295900	,5552520,	10126100	,1577610	,4035.37]
memcelltype2 = [1910150	,16111400,	6866140	,12027700,	4372860,	7973130,	1227000,	3696.39]

# Plot
bar_width = 0.35
index = np.arange(len(layers))

plt.figure(figsize=(12, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('Layers', fontsize=14)
plt.ylabel('Read Dynamic Energy (in pJ)', fontsize=14)
plt.title('Read Dynamic Energy for numRowSubArray/numColSubArray = 1024 in Param.cpp', fontsize=16)
plt.xticks(index + bar_width / 2, layers)
plt.legend()

plt.tight_layout()
plt.show()
