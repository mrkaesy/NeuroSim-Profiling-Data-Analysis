# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [341725,
279924,
268538.00,
237512,
327623]
memcelltype2 = [921164,
606619,
466945,
330939,
383379]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('IC read Dynamic Energy (in pJ)', fontsize=14)
plt.title('IC Read Dynamic Energy for Layer 1', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [1535300.00,
1194700.00,
1111960.00,
938552.00,
1324230.00]
memcelltype2 = [3936940.00,
2548970.00,
1926990.00,
1298290.00,
1507190.00]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('IC read Dynamic Energy (in pJ)', fontsize=14)
plt.title('IC Read Dynamic Energy for Layer 2', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [675935,
526930,
491000,
415122,
585382]
memcelltype2 = [1734770.00,
1124220.00,
850548.00,
573994,
666328]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('IC read Dynamic Energy (in pJ)', fontsize=14)
plt.title('IC Read Dynamic Energy for Layer 3', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [785896,
632347,
608074,
526524,
769844]
memcelltype2 = [2155180.00,
1403190.00,
1065290.00,
719590,
847086]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('IC read Dynamic Energy (in pJ)', fontsize=14)
plt.title('IC Read Dynamic Energy for Layer 4', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [291351,
23470,
225828,
195742,
285962]
memcelltype2 = [799054,
520601,
395457,
267467,
314798]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('IC read Dynamic Energy (in pJ)', fontsize=14)
plt.title('IC Read Dynamic Energy for Layer 5', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [374794,
314567,
314296,
279914,
424647]
memcelltype2 = [1115280.00,
730707,
557350,
377564,
451223]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('IC read Dynamic Energy (in pJ)', fontsize=14)
plt.title('IC Read Dynamic Energy for Layer 6', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [44895.1,
34939.2,
33028.2,
27754.8,
41565.4]
memcelltype2 = [122379,
78236.3,
58472,
38056.1,
45043.1]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('IC read Dynamic Energy (in pJ)', fontsize=14)
plt.title('IC Read Dynamic Energy for Layer 7', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x_coordinates = [64, 128, 256, 512, 1024]
memcelltype1 = [735.696,
666.58,
686.854,
645.93,
929.246]
memcelltype2 = [2232.59,
1527.61,
1205.01,
880.295,
1038.09]

# Plot
bar_width = 0.35
index = np.arange(len(x_coordinates))

plt.figure(figsize=(10, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('numRowSubArray/numColSubArray value in Param.cpp', fontsize=14)
plt.ylabel('IC read Dynamic Energy (in pJ)', fontsize=14)
plt.title('IC Read Dynamic Energy for Layer 8', fontsize=16)
plt.xticks(index + bar_width / 2, x_coordinates)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # How IC Read Dynamic Energy varies with layers?

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
layers = ['Layer1', 'Layer2', 'Layer3', 'Layer4', 'Layer5', 'Layer6', 'Layer7', 'Layer8']
memcelltype1 = [341725,	1535300.00,	675935,	785896,	291351,	374794,	44895.1,	735.696]
memcelltype2 = [921164,	3936940.00,	1734770.00,	2155180.00,	799054,	1115280.00,	122379,	2232.59]

# Plot
bar_width = 0.35
index = np.arange(len(layers))

plt.figure(figsize=(12, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('Layers', fontsize=14)
plt.ylabel('IC Read Dynamic Energy (in pJ)', fontsize=14)
plt.title('IC Read Dynamic Energy for numRowSubArray/numColSubArray = 64 in Param.cpp', fontsize=16)
plt.xticks(index + bar_width / 2, layers)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
layers = ['Layer1', 'Layer2', 'Layer3', 'Layer4', 'Layer5', 'Layer6', 'Layer7', 'Layer8']
memcelltype2 = [606619,	2548970.00,	1124220.00,	1403190.00,	520601,	730707,	78236.3,	1527.61]
memcelltype1 = [279924,	1194700.00,	526930,	632347,	23470,	314567,	34939.2,	666.58]

# Plot
bar_width = 0.35
index = np.arange(len(layers))

plt.figure(figsize=(12, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('Layers', fontsize=14)
plt.ylabel('IC Read Dynamic Energy (in pJ)', fontsize=14)
plt.title('IC Read Dynamic Energy for numRowSubArray/numColSubArray = 128 in Param.cpp', fontsize=16)
plt.xticks(index + bar_width / 2, layers)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
layers = ['Layer1', 'Layer2', 'Layer3', 'Layer4', 'Layer5', 'Layer6', 'Layer7', 'Layer8']
memcelltype2 = [466945,	1926990.00,	850548.00,	1065290.00,	395457,	557350,	58472, 1205.01]
memcelltype1 = [268538.00,	1111960.00,	491000,	608074,	225828,	314296,	33028.2,	686.854]

# Plot
bar_width = 0.35
index = np.arange(len(layers))

plt.figure(figsize=(12, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('Layers', fontsize=14)
plt.ylabel('IC Read Dynamic Energy (in pJ)', fontsize=14)
plt.title('IC Read Dynamic Energy for numRowSubArray/numColSubArray = 256 in Param.cpp', fontsize=16)
plt.xticks(index + bar_width / 2, layers)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
layers = ['Layer1', 'Layer2', 'Layer3', 'Layer4', 'Layer5', 'Layer6', 'Layer7', 'Layer8']
memcelltype2 = [330939,	1298290.00,	573994,	719590,	267467,	377564,	38056.1,	880.295]
memcelltype1 = [237512,	938552.00,	415122,	526524,	195742,	279914,	27754.8,	645.93]

# Plot
bar_width = 0.35
index = np.arange(len(layers))

plt.figure(figsize=(12, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('Layers', fontsize=14)
plt.ylabel('IC Read Dynamic Energy (in pJ)', fontsize=14)
plt.title('IC Read Dynamic Energy for numRowSubArray/numColSubArray = 512 in Param.cpp', fontsize=16)
plt.xticks(index + bar_width / 2, layers)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
layers = ['Layer1', 'Layer2', 'Layer3', 'Layer4', 'Layer5', 'Layer6', 'Layer7', 'Layer8']
memcelltype2 = [383379,	1507190.00,	666328,	847086,	314798,	451223,	45043.1,	1038.09]
memcelltype1 = [327623,	1324230.00,	585382,	769844,	285962,	424647,	41565.4,	929.246]

# Plot
bar_width = 0.35
index = np.arange(len(layers))

plt.figure(figsize=(12, 6))

# Bar for memcelltype = 1
plt.bar(index, memcelltype1, bar_width, label='memcelltype = 1', color='b', alpha=0.6)

# Bar for memcelltype = 2
plt.bar(index + bar_width, memcelltype2, bar_width, label='memcelltype = 2', color='r', alpha=0.6)

# Customizing the plot
plt.xlabel('Layers', fontsize=14)
plt.ylabel('IC Read Dynamic Energy (in pJ)', fontsize=14)
plt.title('IC Read Dynamic Energy for numRowSubArray/numColSubArray = 1024 in Param.cpp', fontsize=16)
plt.xticks(index + bar_width / 2, layers)
plt.legend()

plt.tight_layout()
plt.show()
